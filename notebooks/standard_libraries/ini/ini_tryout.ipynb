# %% [markdown]
# # Sandbox for parsing .ini File
#
# Given a file `config.ini`:

# %%
with open('config.ini') as f:
    print(f.read())
# Out:
# [servers]
# staging = stage.site.com
# production = real.site.com
# port = 4455

# %% [markdown]
# ## Parse It

# %%
from configparser import ConfigParser

config = ConfigParser()
config.read('config.ini')
# Out:
# ['config.ini']

# %%
config.get("servers", "staging")
# Out:
# 'stage.site.com'

# %%
# Get port as an int
config.getint("servers", "port")
# Out:
# 4455

# %%
# Treat it as a nested dictionary
config["servers"]["production"]
# Out:
# 'real.site.com'
