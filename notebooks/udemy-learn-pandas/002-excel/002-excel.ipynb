# %% [markdown]
# # Excel

# %%
import pandas as pd

# %%
df = pd.read_excel("Pens and Papers Collection.xlsx")

# %%
df.head(10)
# Out:
#        Category               Brand                 Model    Color  \
# 0  Fountain Pen                LAMY                  2000    Black
# 1           Ink               Pilot  Iroshizuku Take-Zumi      NaN
# 2  Fountain Pen               Pilot          Metropolitan    Black
# 3  Fountain Pen               Pilot             Custom 74     Teal
# 4  Fountain Pen               Pilot            Custom 823    Smoke
# 5        Marker            Kuretake   ZIG Clean Color Dot  Various
# 6         Ruler              Midori           Multi-ruler      NaN
# 7           Ink             Noodler  North African Violet   Purple
# 8  Fountain Pen               Pilot          Metropolitan   Purple
# 9      Notebook  Jumping Fox Design      Bullet Dotted A5     Blue
#
#          Note Nib Size Purchase Date   Price     Retailer
# 0         NaN     Fine    2020-11-14  144.85       Amazon
# 1         NaN      NaN    2020-11-14   24.95       Amazon
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df[Category=="Fountain Pen"]
#
# NameError: name 'Category' is not defined
